# %% [markdown]
# ### This notebook is to study the dataframes that we generate, specially the total ones.

# %%
import pandas as pd

types = {"ID": int, "Genotype": str, "Energy": float, "Age": int, "Parent": int, "Iteration": int,}
df = pd.read_csv("data/total_0_25.csv", dtype=types, header=0)
df.max()
# Out:
# ID                           7877
# Genotype     11111111011010101110
# Energy                   14.99635
# Age                             6
# Parent                       7540
# Iteration                     100
# dtype: object

# %%
first = df[df.Iteration == 0]
genotypes = list(first.Genotype)
print(len(genotypes))
# Out:
# 100

# %%
import functions.distance as dist

hammin = dist.study_distance(genotypes, "hamming")
# Out:
# Computing hamming distance

# %%
print(hammin)
print(len(hammin))
# Out:
# [11, 7, 12, 10, 3, 12, 11, 13, 8, 7, 13, 10, 8, 11, 7, 12, 6, 7, 11, 7, 9, 13, 6, 8, 12, 10, 5, 9, 10, 8, 12, 15, 14, 11, 10, 9, 15, 10, 10, 10, 9, 8, 12, 8, 8, 12, 10, 11, 10, 7, 12, 12, 9, 11, 13, 7, 12, 12, 9, 10, 11, 7, 10, 9, 10, 6, 12, 12, 9, 8, 9, 9, 6, 9, 9, 10, 8, 9, 10, 10, 9, 7, 8, 6, 10, 10, 11, 8, 12, 13, 7, 8, 13, 13, 11, 9, 9, 12, 9, 14, 9, 11, 12, 11, 6, 6, 13, 8, 8, 11, 13, 10, 10, 11, 11, 8, 8, 10, 12, 12, 11, 11, 7, 11, 10, 12, 11, 13, 9, 8, 11, 8, 13, 12, 14, 9, 7, 13, 8, 13, 11, 7, 9, 5, 9, 6, 9, 12, 9, 7, 10, 12, 14, 12, 11, 7, 12, 9, 10, 10, 11, 12, 13, 9, 9, 3, 12, 9, 10, 6, 9, 10, 10, 7, 13, 10, 9, 9, 8, 10, 9, 13, 15, 11, 12, 7, 9, 12, 12, 11, 8, 10, 10, 10, 10, 9, 14, 9, 7, 8, 9, 10, 12, 7, 12, 10, 9, 7, 8, 6, 9, 9, 12, 10, 8, 8, 10, 9, 11, 13, 7, 10, 6, 13, 9, 13, 10, 9, 10, 11, 12, 10, 11, 11, 9, 8, 5, 9, 13, 7, 13, 9, 10, 13, 6, 11, 15, 10, 10, 8, 10, 11, 9, 10, 11, 12, 10, 9, 6, 5, 11, 13, 11, 10, 9, 10, 12, 11, 12, 12, 13, 9, 12, 13, 9, 10, 8, 9, 9, 9,
# ...

# %%
last = df[df.Iteration == 100]
genotypes2 = list(last.Genotype)
print(len(genotypes))
# Out:
# 100

# %%
hammin2 = dist.study_distance(genotypes2, "hamming")
print(len(hammin2))
# Out:
# Computing hamming distance
# 63903
